# %%
#install.packages('BETS', dependencies = TRUE)
#install.packages('forecast')

library(forecast)
library(BETS)

## ERRO AO INSTALAR PACOTE BETS !!!

## Trazendo a série temporal de nível de emprego formal com o pacote BETS

# %%
## Trazendo a série temporal de nível de emprego formal com o pacote BETS

emprego <- BETSget(code = 12779)
plot(emprego)
str(emprego)
# Out:
#  Time-Series [1:278] from 1996 to 2019: 97.6 97.4 97.5 97.9 98.2 ...
# plot without title

# %%
# Próximos passos - usar a serie temporal de emprego acima como antecedente de determinado tipo de crime
